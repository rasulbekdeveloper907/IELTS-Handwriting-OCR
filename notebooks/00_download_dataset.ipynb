# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ByXr9BebeyCvj8HDECCI")
project = rf.workspace("rasulbeks-workspace-bwa7o").project("ielts-handwriting-ocr")
version = project.version(1)
dataset = version.download("folder")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.3.9-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: certifi in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (2026.4.22)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (3.10.8)
# Requirement already satisfied: numpy>=1.18.5 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (2.4.3)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (12.1.1)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.3.0-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp313-cp313-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: python-dateutil in C:\Users\Rasulbekk\AppData\Roaming\Python\Python313\site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: requests in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (2.33.1)
# Requirement already satisfied: six in C:\Users\Rasulbekk\AppData\Roaming\Python\Python313\site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (2.6.3)
# Requirement already satisfied: tqdm>=4.41.0 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (4.67.3)
# Requirement already satisfied: PyYAML>=5.3.1 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (6.0.3)
# Collecting requests_toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typer<0.26,>=0.12.0 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (0.25.0)
# Requirement already satisfied: click>=8.0 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from roboflow) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer<0.26,>=0.12.0->roboflow) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: colorama in C:\Users\Rasulbekk\AppData\Roaming\Python\Python313\site-packages (from click>=8.0->roboflow) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Rasulbekk\AppData\Roaming\Python\Python313\site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->roboflow) (4.62.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Rasulbekk\AppData\Roaming\Python\Python313\site-packages (from matplotlib->roboflow) (26.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Rasulbekk\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests->roboflow) (3.4.7)
# Downloading roboflow-1.3.9-py3-none-any.whl (249 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.8 MB 3.5 MB/s eta 0:00:12
#    - -------------------------------------- 1.6/38.8 MB 4.5 MB/s eta 0:00:09
#    -- ------------------------------------- 2.1/38.8 MB 4.5 MB/s eta 0:00:09
#    --- ------------------------------------ 3.1/38.8 MB 4.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 3.9/38.8 MB 4.1 MB/s eta 0:00:09
#    ---- ----------------------------------- 4.7/38.8 MB 4.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 5.5/38.8 MB 4.0 MB/s eta 0:00:09
#    ------ --------------------------------- 6.3/38.8 MB 4.0 MB/s eta 0:00:09
#    ------- -------------------------------- 7.1/38.8 MB 4.0 MB/s eta 0:00:09
#    -------- ------------------------------- 7.9/38.8 MB 3.9 MB/s eta 0:00:08
#    -------- ------------------------------- 8.7/38.8 MB 3.9 MB/s eta 0:00:08
#    --------- ------------------------------ 9.4/38.8 MB 3.9 MB/s eta 0:00:08
#    --------- ------------------------------ 9.4/38.8 MB 3.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.5/38.8 MB 3.8 MB/s eta 0:00:08
#    ----------- ---------------------------- 11.5/38.8 MB 3.8 MB/s eta 0:00:08
#    ------------ --------------------------- 12.3/38.8 MB 3.8 MB/s eta 0:00:07
#    ------------- -------------------------- 13.1/38.8 MB 3.8 MB/s eta 0:00:07
#    -------------- ------------------------- 13.9/38.8 MB 3.8 MB/s eta 0:00:07
#    --------------- ------------------------ 14.7/38.8 MB 3.8 MB/s eta 0:00:07
#    --------------- ------------------------ 15.5/38.8 MB 3.8 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.5/38.8 MB 3.9 MB/s eta 0:00:06
#    ----------------- ---------------------- 17.3/38.8 MB 3.9 MB/s eta 0:00:06
#    ------------------ --------------------- 18.1/38.8 MB 3.9 MB/s eta 0:00:06
#    -------------------- ------------------- 19.4/38.8 MB 4.0 MB/s eta 0:00:05
#    --------------------- ------------------ 20.4/38.8 MB 4.0 MB/s eta 0:00:05
#    --------------------- ------------------ 21.2/38.8 MB 4.0 MB/s eta 0:00:05
#    ---------------------- ----------------- 22.3/38.8 MB 4.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 23.1/38.8 MB 4.0 MB/s eta 0:00:04
#    ------------------------ --------------- 23.9/38.8 MB 4.1 MB/s eta 0:00:04
#    ------------------------- -------------- 24.9/38.8 MB 4.1 MB/s eta 0:00:04
#    -------------------------- ------------- 26.0/38.8 MB 4.1 MB/s eta 0:00:04
#    --------------------------- ------------ 26.7/38.8 MB 4.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 27.5/38.8 MB 4.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.6/38.8 MB 4.1 MB/s eta 0:00:03
#    ------------------------------ --------- 29.9/38.8 MB 4.2 MB/s eta 0:00:03
#    ------------------------------- -------- 30.7/38.8 MB 4.2 MB/s eta 0:00:02
#    -------------------------------- ------- 31.7/38.8 MB 4.2 MB/s eta 0:00:02
#    --------------------------------- ------ 32.8/38.8 MB 4.2 MB/s eta 0:00:02
#    ---------------------------------- ----- 33.6/38.8 MB 4.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 34.3/38.8 MB 4.2 MB/s eta 0:00:02
#    ------------------------------------ --- 35.4/38.8 MB 4.2 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/38.8 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.8 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 4.2 MB/s  0:00:09
# Downloading pi_heif-1.3.0-cp313-cp313-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------- ----------------------- 0.8/1.9 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/1.9 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 4.4 MB/s  0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp313-cp313-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.9 MB 4.7 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.9 MB 4.0 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/9.9 MB 4.0 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/9.9 MB 3.9 MB/s eta 0:00:02
#    --------------- ------------------------ 3.9/9.9 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 4.7/9.9 MB 4.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.9 MB 4.1 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.9 MB 4.1 MB/s eta 0:00:01
#    ------------------------------ --------- 7.6/9.9 MB 4.2 MB/s eta 0:00:01
#    --------------------------------- ------ 8.4/9.9 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 4.2 MB/s  0:00:02
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, python-dotenv, pi-heif, opencv-python-headless, idna, requests_toolbelt, roboflow
#
#    ----- ---------------------------------- 1/8 [filetype]
#    ----- ---------------------------------- 1/8 [filetype]
#    ---------- ----------------------------- 2/8 [python-dotenv]
#    --------------- ------------------------ 3/8 [pi-heif]
#    --------------- ------------------------ 3/8 [pi-heif]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#   Attempting uninstall: idna
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#     Found existing installation: idna 3.13
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#     Uninstalling idna-3.13:
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#       Successfully uninstalled idna-3.13
#    -------------------- ------------------- 4/8 [opencv-python-headless]
#    ------------------------- -------------- 5/8 [idna]
#    ------------------------------ --------- 6/8 [requests_toolbelt]
#    ------------------------------ --------- 6/8 [requests_toolbelt]
#    ------------------------------ --------- 6/8 [requests_toolbelt]
#    ------------------------------ --------- 6/8 [requests_toolbelt]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ----------------------------------- ---- 7/8 [roboflow]
#    ---------------------------------------- 8/8 [roboflow]
#
# Successfully installed filetype-1.2.0 idna-3.7 opencv-python-headless-4.10.0.84 pi-heif-1.3.0 pillow-avif-plugin-1.5.5 python-dotenv-1.2.2 requests_toolbelt-1.0.0 roboflow-1.3.9
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in IELTS-Handwriting-OCR-1 to folder:: 100%|██████████| 369/369 [00:00<00:00, 560.39it/s]
# Extracting Dataset Version Zip to IELTS-Handwriting-OCR-1 in folder:: 100%|██████████| 38/38 [00:00<00:00, 885.74it/s]
